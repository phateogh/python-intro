# %%
name = input("What is your name? ")
age = input("How old are you? ")
print("\nHello, ",  name + "!") 
print("you are", age, "years old.") 
print("welcome to the world of python programming!")
# Out:
# Hello,  osaretin Faith!
# you are 15 years old.
# welcome to the world of python programming!

# %%
name = input("what is your name? ")
level = input("what is your level? ")

department = input("what is your department? ")
hobby = input("what is your hobby? ")
print("welcome, ", name + "!")
print("you have been enrolled to", level, "in", department, "department.")
print("we have noted you are good at", hobby )

# %%
acceptable_age = (16)
student_age = int(input("please enter your age:"))
if student_age >= 16:       
    print("welcome")
else:
    print(" not eligible")
# Out:
#  not eligible

# %%
print("=" * 50)
print("             rfk;lk;xl;dg;l")
print("=" * 50)
# Out:
# ==================================================
#              rfk;lk;xl;dg;l
# ==================================================

# %%
print("=" * 50)
print("        PYTHON LEARNER IDENTITY CARD")
print("=" * 50)
fullname = input("Enter your full name:")
age = input("Enter your age:")
country = input("Enter your country:")
focus_area = input("Favourite python use case:")
course_goal = input("Your goal for this course:")
# Out:
# ==================================================
#         PYTHON LEARNER IDENTITY CARD
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 print("=" * 50)
#       2 print("        PYTHON LEARNER IDENTITY CARD")
#       3 print("=" * 50)
# ----> 4 fullname = input("Enter your full name:")
#       5 age = input("enter your age")
#       6 country = input("Enter your country")
#       7 focus_area = input("favourite python use case")
#
# File c:\Users\Open User\Desktop\practice\myvenv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Users\Open User\Desktop\practice\myvenv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
